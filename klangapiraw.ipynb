# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv, print 5 rows
klangapi = pd.read_csv('klangapiraw.csv',encoding='latin1')
klangapi.head()
# Out:
#   Full_Date    Month  Years Site_Id  \
# 0  1/1/2002  January   2002  CA0011
# 1  1/1/2002  January   2002  CA0011
# 2  1/1/2002  January   2002  CA0011
# 3  1/1/2002  January   2002  CA0011
# 4  1/1/2002  January   2002  CA0011
#
#                                        Site_Location      Date  Time  \
# 0  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   100
# 1  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   200
# 2  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   300
# 3  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   400
# 4  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   500
#
#    Ws_hourly_avg  Wd_hourly_avg  Amb_temp_hourly_avg  ...  \
# 0            2.6          355.0                 26.9  ...
# 1            3.0           34.0                 26.7  ...
# 2            3.2           54.0                 26.1  ...
# 3            2.9          113.0                 25.5  ...
# ...

# %%
klangapi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160260 entries, 0 to 160259
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Full_Date            160260 non-null  object
#  1   Month                160260 non-null  object
#  2   Years                160260 non-null  int64
#  3   Site_Id              160260 non-null  object
#  4   Site_Location        160260 non-null  object
#  5   Date                 160260 non-null  int64
#  6   Time                 160260 non-null  int64
#  7   Ws_hourly_avg        125313 non-null  float64
#  8   Wd_hourly_avg        143277 non-null  float64
#  9   Amb_temp_hourly_avg  152851 non-null  float64
#  10  UVB_hourly_avg       78737 non-null   float64
#  11  Humidity_hourly_avg  153637 non-null  object
#  12  Nox_hourly_avg       158628 non-null  object
#  13  No_hourly_avg        158628 non-null  object
#  14  So2_hourly_avg       158809 non-null  object
# ...

# %%
klangapi["Humidity_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["Nox_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["Nox_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["No_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["So2_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["No2_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["O3_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["Co_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')
klangapi["Pm10_hourly_avg"] = pd.to_numeric(klangapi.Humidity_hourly_avg, errors='coerce')

# %%
klangapi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160260 entries, 0 to 160259
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Full_Date            160260 non-null  object
#  1   Month                160260 non-null  object
#  2   Years                160260 non-null  int64
#  3   Site_Id              160260 non-null  object
#  4   Site_Location        160260 non-null  object
#  5   Date                 160260 non-null  int64
#  6   Time                 160260 non-null  int64
#  7   Ws_hourly_avg        125313 non-null  float64
#  8   Wd_hourly_avg        143277 non-null  float64
#  9   Amb_temp_hourly_avg  152851 non-null  float64
#  10  UVB_hourly_avg       78737 non-null   float64
#  11  Humidity_hourly_avg  147367 non-null  float64
#  12  Nox_hourly_avg       147367 non-null  float64
#  13  No_hourly_avg        147367 non-null  float64
# ...

# %%
#check is missing data exist
klangapi.isnull().sum()
# Out:
# Full_Date                   0
# Month                       0
# Years                       0
# Site_Id                     0
# Site_Location               0
# Date                        0
# Time                        0
# Ws_hourly_avg           34947
# Wd_hourly_avg           16983
# Amb_temp_hourly_avg      7409
# UVB_hourly_avg          81523
# Humidity_hourly_avg     12893
# Nox_hourly_avg          12893
# No_hourly_avg           12893
# So2_hourly_avg          12893
# No2_hourly_avg          12893
# O3_hourly_avg           12893
# Co_hourly_avg           12893
# Pm10_hourly_avg         12893
# API_Main                  531
# PM2.5 1H (µg/m3)       134129
# dtype: int64

# %%
klangapi.interpolate(method ='linear', limit_direction ='both', inplace=True)

# %%
klangapi.isnull().sum()
# Out:
# Full_Date              0
# Month                  0
# Years                  0
# Site_Id                0
# Site_Location          0
# Date                   0
# Time                   0
# Ws_hourly_avg          0
# Wd_hourly_avg          0
# Amb_temp_hourly_avg    0
# UVB_hourly_avg         0
# Humidity_hourly_avg    0
# Nox_hourly_avg         0
# No_hourly_avg          0
# So2_hourly_avg         0
# No2_hourly_avg         0
# O3_hourly_avg          0
# Co_hourly_avg          0
# Pm10_hourly_avg        0
# API_Main               0
# PM2.5 1H (µg/m3)       0
# dtype: int64

# %%
klangapi.head()
# Out:
#   Full_Date    Month  Years Site_Id  \
# 0  1/1/2002  January   2002  CA0011
# 1  1/1/2002  January   2002  CA0011
# 2  1/1/2002  January   2002  CA0011
# 3  1/1/2002  January   2002  CA0011
# 4  1/1/2002  January   2002  CA0011
#
#                                        Site_Location      Date  Time  \
# 0  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   100
# 1  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   200
# 2  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   300
# 3  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   400
# 4  Sek. Men. (P) Raja Zarina, Kelang             ...  20020101   500
#
#    Ws_hourly_avg  Wd_hourly_avg  Amb_temp_hourly_avg  ...  \
# 0            2.6          355.0                 26.9  ...
# 1            3.0           34.0                 26.7  ...
# 2            3.2           54.0                 26.1  ...
# 3            2.9          113.0                 25.5  ...
# ...

# %%
klangapi['Date'] = pd.to_datetime(klangapi['Date'], format='%Y%m%d')

# %%
klangapi.set_index('Date', inplace=True)
klangapi.head()
# Out:
#            Full_Date    Month  Years Site_Id  \
# Date
# 2002-01-01  1/1/2002  January   2002  CA0011
# 2002-01-01  1/1/2002  January   2002  CA0011
# 2002-01-01  1/1/2002  January   2002  CA0011
# 2002-01-01  1/1/2002  January   2002  CA0011
# 2002-01-01  1/1/2002  January   2002  CA0011
#
#                                                 Site_Location  Time  \
# Date
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...   100
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...   200
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...   300
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...   400
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...   500
#
#             Ws_hourly_avg  Wd_hourly_avg  Amb_temp_hourly_avg  UVB_hourly_avg  \
# Date
# 2002-01-01            2.6          355.0                 26.9             0.0
# 2002-01-01            3.0           34.0                 26.7             0.0
# ...

# %%
klangapinews = klangapi.resample('D').mean()

# %%
klangapi
# Out:
#              Full_Date     Month  Years Site_Id  \
# Date
# 2002-01-01    1/1/2002   January   2002  CA0011
# 2002-01-01    1/1/2002   January   2002  CA0011
# 2002-01-01    1/1/2002   January   2002  CA0011
# 2002-01-01    1/1/2002   January   2002  CA0011
# 2002-01-01    1/1/2002   January   2002  CA0011
# ...                ...       ...    ...     ...
# 2020-12-31  31/12/2020  December   2020   CA21B
# 2020-12-31  31/12/2020  December   2020   CA21B
# 2020-12-31  31/12/2020  December   2020   CA21B
# 2020-12-31  31/12/2020  December   2020   CA21B
# 2020-12-31  31/12/2020  December   2020   CA21B
#
#                                                 Site_Location   Time  \
# Date
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...    100
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...    200
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...    300
# 2002-01-01  Sek. Men. (P) Raja Zarina, Kelang             ...    400
# ...

# %%
klangapinews
# Out:
#              Years          Time  Ws_hourly_avg  Wd_hourly_avg  \
# Date
# 2002-01-01  2002.0   1250.000000       5.150000     152.208333
# 2002-01-02  2002.0   1250.000000       5.670833     156.833333
# 2002-01-03  2002.0   1250.000000       5.529167     107.375000
# 2002-01-04  2002.0   1250.000000       5.308333     140.208333
# 2002-01-05  2002.0   1250.000000       5.000000     145.250000
# ...            ...           ...            ...            ...
# 2020-12-27  2020.0  44192.458333       1.117042     122.541667
# 2020-12-28  2020.0  44193.500000       0.810708     179.291667
# 2020-12-29  2020.0  44194.458333       1.168000     162.000000
# 2020-12-30  2020.0  44195.500000       1.264167     138.125000
# 2020-12-31  2020.0  44196.458333       1.218042     158.166667
#
#             Amb_temp_hourly_avg  UVB_hourly_avg  Humidity_hourly_avg  \
# Date
# 2002-01-01            28.270833      114.041667            89.000000
# ...

# %%
#2002-01-01 to 2020-12-31
#6940 days
#remove uvb, rh rows, year
#training/testing 2002-2018
#deployment 2019-2020, in stat verification
#gru:improvement lstm: get recurrent unit ,lstm
